# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('combined_emotion.csv')

# %%
df.sample(5)
# Out:
#                                                  sentence emotion
# 407507               i know how it feels like to get hurt     sad
# 289942  i am feeling especially discontent today or ra...     sad
# 294136  i am doing these things which is reassuring i ...    love
# 400543  i didnt feel like getting neurotic so decided ...    fear
# 89078             i just can t help but feel insecure now    fear

# %%
df['emotion'].value_counts()
# Out:
# emotion
# joy        143067
# sad        121187
# anger       59317
# fear        49649
# love        34554
# suprise     14972
# Name: count, dtype: int64

# %%
sns.countplot(x='emotion',data=df)
# Out:
# <Axes: xlabel='emotion', ylabel='count'>

# %%
import nltk

nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import emoji

# Initialize tools
stop_words = set(stopwords.words("english"))

#  Important: Keep negation words
negation_words = {"not", "no", "nor", "never"}
stop_words = stop_words - negation_words

lemmatizer = WordNetLemmatizer()


def clean_text(text):
    # 1.Lowercase
    text = text.lower()
    
    # 2.Remove URLs
    text = re.sub(r"http\S+", "", text)
    
    # 3.Remove mentions
    text = re.sub(r"@\w+", "", text)
    
    # 4. Remove hashtags symbol only
    text = re.sub(r"#", "", text)
    
    # 5. Remove special characters & numbers
    text = re.sub(r"[^a-z\s]", "", text)
    
    # 6. Handaling emoji in text
    text = emoji.demojize(text)
    
    # 7. Tokenize
    tokens = word_tokenize(text)
    
    # 8. Remove stopwords
    tokens = [word for word in tokens if word not in stop_words]
    
    # 9. Lemmatize
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    
    # 10. Join words back
    return " ".join(tokens)

# %%
df["Clean_Text"] = df["sentence"].apply(clean_text)

# Show result
print(df[["emotion", "Clean_Text"]].head())
# Out:
#   emotion                                         Clean_Text
# 0    fear                 feel really helpless heavy hearted
# 1     sad  ive enjoyed able slouch relax unwind frankly n...
# 2    fear            gave internship dmrg feeling distraught
# 3     sad                                dont know feel lost
# 4    fear  kindergarten teacher thoroughly weary job take...

# %%
df.sample(5)
# Out:
#                                                  sentence emotion  \
# 21215   i use a napkin to wrap the bottom half of my f...    fear
# 321356  i feel kinda troubled but like always its way ...     sad
# 361905  i feel no longing only gladness when it passes...    love
# 32617   i didnt feel so much of not mattering or no on...    love
# 273939        i did not feel love from the men who abused     sad
#
#                                                Clean_Text
# 21215   use napkin wrap bottom half face feeling restl...
# 321356  feel kinda troubled like always way better kee...
# 361905  feel no longing gladness pass least amount ruc...
# 32617         didnt feel much not mattering no one caring
# 273939                           not feel love men abused

# %%
X = df[['Clean_Text']]
Y = df[['emotion']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X,
    Y,
    test_size=0.2,
    random_state=42,
    stratify=Y
)

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.compose import ColumnTransformer
from sklearn.naive_bayes import MultinomialNB

# %%
vectorizer = TfidfVectorizer(
    max_features=10000,
    ngram_range=(1,2),
    min_df=2,          # ignore rare words
    max_df=0.9,        # ignore very common words
    sublinear_tf=True  # improves performance
)

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('cv',vectorizer,'Clean_Text'),
    ]
)

# %%
pipe_lr = Pipeline(steps=[
    
    ('preprocessor',preprocessor),
    ('classifier',LogisticRegression(C=3.0, class_weight='balanced', max_iter=1000))
])
pipe_lr.fit(X_train,Y_train)
